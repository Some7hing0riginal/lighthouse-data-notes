# %%
# import seaborn
import seaborn as sns

# import matplotlib
import matplotlib.pyplot as plt

# load the built-in tips dataset
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# a regression line with a confidence inetrval plot
sns.lmplot(x='total_bill', y='tip', data = tips)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip', data = tips, hue = 'sex')
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip', data = tips, col = 'sex')
plt.show()

# %%
sns.residplot(x='total_bill',y='tip', data = tips)
plt.show()

# %%
#Strip plot
sns.stripplot(x='day',y ='tip',data = tips, size =5, jitter = True)

# overwrite the original y-label from 'tip' to 'tip ($)'
plt.ylabel('tip ($)')
plt.show()

# %%
#SWARM plot
sns.swarmplot(x='day',y='tip',data = tips, hue = 'sex')

# overwrite the original y-label from 'tip' to 'tip ($)'
plt.ylabel('tip ($)')
plt.show()
# Out:
# /home/owner/anaconda3/envs/bootcampEnv/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/owner/anaconda3/envs/bootcampEnv/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#Boxplot + violin
# create a grid with 1 row 2 columns
plt.subplot(1,2,1)

# the first plot
sns.boxplot(x='day',y='tip', data = tips)
plt.ylabel('tip ($)')

plt.subplot(1,2,2)

# the second plot
sns.violinplot(x='day',y='tip', data = tips)
plt.ylabel('tip ($)')
plt.tight_layout()
plt.show()

# %%
#Joint plot
sns.jointplot(x='total_bill', y='tip', data = tips)
plt.show()

# %%
sns.jointplot(x='total_bill', y='tip', data = tips, kind = 'kde')
plt.show()

# %%
sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(tips, hue = 'sex')
plt.show()

# %%
# compute correlations between features
df_corr = tips.corr()

# plot the correlations
sns.heatmap(df_corr)
plt.title('Correlation plot')
plt.show()
